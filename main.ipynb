# %% [markdown]
# ### 1. Create dictionaries
# * dictionary to contain every item in house
# * lists of all rooms and all "physical" keys
# * relational dictionaries to see how items are connected
# * initial dictionary to track game state

# %%
couch = {
    "name": "couch",
    "type": "furniture",
    "ASCII": """
        .-='''''''''''=-.
        | . . . . . . . |
        | .'.'.'.'.'.'. |
       ()_______________()
       ||_______________||
        W               W
    
    """,
}
piano = {
    "name": "piano",
    "type": "furniture",
    "ASCII": """
    
             _   _       _   _   _       _   _       _   _   _      
         |__//|_//|_____//|_//|_//|_____//|_//|_____//|_//|_//|__| 
        /  /// ///  /  /// /// ///  /  /// ///  /  /// /// ///  / /
       /  ||/ ||/  /  ||/ ||/ ||/  /  ||/ ||/  /  ||/ ||/ ||/  / /
      /___/___/___/___/___/___/___/___/___/___/___/___/___/___/ /
      |___|___|___|___|___|___|___|___|___|___|___|___|___|___|/
    
    """,
}
double_bed = {
    "name": "double bed",
    "type": "furniture",
    "ASCII": """
    
       ()___ 
     ()//__/)_________________()
     ||(___)//#/_/#/_/#/_/#()/||
     ||----|#| |#|_|#|_|#|_|| ||
     ||____|_|#|_|#|_|#|_|#||/||
     ||    |#|_|#|_|#|_|#|_||
    
    """,
}
dresser = {
    "name": "dresser",
    "type": "furniture",
    "ASCII": """
          _______
         |_o_|_o_|
         |___o___|
         |___o___|
         |___o___| 
          ||   ||
    
    """,
}
queen_bed = {
    "name": "queen bed",
    "type": "furniture",
    "ASCII": """
              ()
     () .'_`'.||
     ||/.| ||\ |
     | /|| || ||         _   ()
     || || || ||    () .'_`'.||
     || || || ||    ||/.| ||\ |
     || || |I-'`-._ | /|| || ||
     ||_I'`_.-||-._`'| || || ||
     |._ <'_  ||   `|| || || ||
     || `-._`-'|    || || |I-'|
     ()     `-._`-._||_I'`_.-||
                `-._` _.-'   ()
                    ||       `
                    ()

    """,
}
dining_table = {
    "name": "dining table",
    "type": "furniture",
    "ASCII": """
                     ,%;,
                     ,%%,
        ______________)(______________    
       /             (__)             \    
      /________________________________\    
      [________________________________]    
         \ \  / /            \ \  / /    
          \ \/ /              \ \/ /    
          _\/ /________________\ \/_    
         [_/o/__________________\o\_]    
          / /\ \              / /\ \    
         lc/  \_\            /_/  \_\    
                        
    """,
}
game_room = {
    "name": "game room",
    "type": "room",
}
bedroom_1 = {
    "name": "bedroom one",
    "type": "room",
}
bedroom_2 = {
    "name": "bedroom two",
    "type": "room",
}
living_room = {
    "name": "living room",
    "type": "room",
}
outside = {
    "name": "outside",
}
door_a = {
    "name": "door a",
    "type": "door",
}
door_b = {
    "name": "door b",
    "type": "door",
}
door_c = {
    "name": "door c",
    "type": "door",
}
door_d = {
    "name": "door d",
    "type": "door",
}
key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,

}
key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,

}
key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,

}
key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,

}

ASCII = {
    "key":
    """
    
                                 ,ooo.       
     8a8 8a8                    oP   ?b
    d888a888zzzzzzzzzzzzzzzzzzzz8     8b
     `""^""'                    ?o___oP'
    
    """,
    "door open":"""
    

             /|
            / |
           /__|______
          |  __  __  |
          | |  ||  | | 
          | |__||__| |
          |  __  __()|
          | |  ||  | |
          | |  ||  | |
          | |__||__| |
          |__________|  

          """,
    "door closed": """
             __________
            |  __  __  |
            | |  ||  | |
            | |  ||  | |
            | |__||__| |
            |  __  __()|
            | |  ||  | |
            | |  ||  | |
            | |  ||  | |
            | |  ||  | |
            | |__||__| |
            |__________|
                                
    """,
    "winner": """
    
    
                                         .''.
           .''.             *''*    :_\/_:     . 
          :_\/_:   .    .:.*_\/_*   : /\ :  .'.:.'.
      .''.: /\ : _\(/_  ':'* /\ *  : '..'.  -=:o:=-
     :_\/_:'.:::. /)\*''*  .|.* '.\'/.'_\(/_'.':'.'
     : /\ : :::::  '*_\/_* | |  -= o =- /)\    '  *
      '..'  ':::'   * /\ * |'|  .'/.\'.  '._____
          *        __*..* |  |     :      |.   |' .---"|
           _*   .-'   '-. |  |     .--'|  ||   | _|    |
        .-'|  _.|  |    ||   '-__  |   |  |    ||      |
        |' | |.    |    ||       | |   |  |    ||      |
     ___|  '-'     '    ""       '-'   '-.'    '`      |____
    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    
    """,
        
}

# %%
all_rooms = [game_room, bedroom_1, bedroom_2, living_room, outside]
all_doors = [door_a, door_b, door_c, door_d]

# %%
object_relations = {
    "game room": [couch, piano, door_a],
    "bedroom one": [queen_bed, door_a, door_b, door_c], 
    "bedroom two": [double_bed, dresser, door_b],
    "living room": [dining_table, door_c, door_d],
    "outside": [door_d],
    "piano": [key_a],
    "queen bed": [key_b],
    "double bed": [key_c],
    "dresser": [key_d],
    "door a": [game_room, bedroom_1],
    "door b": [bedroom_1, bedroom_2],
    "door c": [bedroom_1, living_room],
    "door d": [living_room, outside],
    }

# %%
initial_game_state = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside,
}

# %% [markdown]
# ### 2. Start to create basic functions
# * line break function
#     * goal: be able to break a line in text when desired
# * start-game function
#     * goal: initial game play by presenting situation and starting to play the specific room
# * play-room function
#     * goal: asseses if you have escaped the specific room, if not prompts the user to call a function to explore or examine the room

# %%
def line_break():
    print("\n\n")

# %%
def start_game():
    print("""
                                                 _
                                              _-'_'-_
                                           _-' _____ '-_
                                        _-' ___________ '-_
                                         |___|||||||||___|
                                         |___|||||||||___|
                                         |___|||||||o|___|
                                         |___|||||||||___|
                                         |___|||||||||___|
                                         |___|||||||||___|


          You wake up on a couch and find yourself in a strange house with no windows
          which you have never been to before. You don't remember why you are here and what 
          had happened before. You feel some unknown danger is approaching and you must get 
          out of the house, NOW!""")
    play_room(game_state["current_room"])

# %%
def play_room(room):
    game_state["current_room"] = room
    if(game_state["current_room"] == game_state["target_room"]):
        print(ASCII["winner"] + "Congrats! You escaped the room!")
    else:
        print("You are now in " + room["name"])
        intended_action = input("What would you like to do? Type 'explore' or 'examine'?").strip()
        if intended_action == "explore":
            explore_room(room)
            play_room(room)
        elif intended_action == "examine":
            examine_item(input("What would you like to examine?").strip())
        else:
            print("Not sure what you mean. Type 'explore' or 'examine'.")
            play_room(room)
        line_break()

# %% [markdown]
# ### 3. Create explore/examine/next room functions
# * explore function: lists all items in a room
# * next room function: finds the room to which the current room is connected
# * examine function:
#     * can only examine furniture or doors
#     * checks if item belongs to that room
#     * if it is a door:
#         * key not found, notifies player
#         * key found, askes player if they want to go to next room
#     * if it is furniture:
#         * checks to see if the item contains a key
#         * if yes, collects key and updates game status
#         * if no, returns that noting was found and triggers play_room to restart
#     * depending on game state, will either end by playing same room or next room

# %%
def explore_room(room):
    items = [i["name"] for i in object_relations[room["name"]]]
    print("You explore the room. This is " + room["name"] + ". You find " + ", ".join(items))

# %%
def get_next_room_of_door(door, current_room):
    connected_rooms = object_relations[door["name"]]
    for room in connected_rooms:
        if(not current_room == room):
            return room

# %%
def examine_item(item_name):
    
    current_room = game_state["current_room"]
    next_room = ""
    output = None
    
    for item in object_relations[current_room["name"]]:
        if(item["name"] == item_name):
            output = "You examine the " + item_name + ". "
            if(item["type"] == "door"):
                have_key = False
                for key in game_state["keys_collected"]:
                    if(key["target"] == item):
                        have_key = True
                if(have_key):
                    output += ASCII["door open"] + "You unlock it with a key you have."
                    next_room = get_next_room_of_door(item, current_room)
                else:
                    output += ASCII["door closed"] + "It is locked but you don't have the key."
            else:
                output += item["ASCII"]
                if(item["name"] in object_relations and len(object_relations[item["name"]])>0):
                    item_found = object_relations[item["name"]].pop()
                    game_state["keys_collected"].append(item_found)
                    output += ASCII["key"] + "You find a " + item_found["name"] + "."
                else:
                    output += "There isn't anything interesting about it."

            print(output)
            break

    if(output is None):
        print("The item you requested is not found in the current room.")
    
    if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'):
        play_room(next_room)
    else:
        play_room(current_room)

# %% [markdown]
# ### 4. Make fun modifications
# * give the house a visual
# * create a dictionary with ASCII symbols for door open/close and keys
# * create visuals for each object

# %% [markdown]
# ### 5. Play the Game!

# %%
game_state = initial_game_state.copy()

# %%
start_game()
